# %%
pip install geopy pandas
# Out:
# Collecting geopy
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: pandas in ./anaconda3/lib/python3.11/site-packages (2.0.3)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Obtaining dependency information for geographiclib<3,>=1.52 from https://files.pythonhosted.org/packages/9f/5a/a26132406f1f40cf51ea349a5f11b0a46cec02a2031ff82e391c2537247a/geographiclib-2.0-py3-none-any.whl.metadata
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in ./anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in ./anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in ./anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 3.8 MB/s eta 0:00:00
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
###Geocoding using geopy

import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# Initialize the geocoder with Nominatim
geolocator = Nominatim(user_agent="myGeocoder")

# Set up rate limiter to avoid being blocked by the server (2 seconds delay)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=2)

# Load your dataset (assumes a CSV file with a column named 'Address')
data = pd.read_csv("/Users/supriya/Downloads/Banking Export Data CSV-5.csv")

# Function to apply geocoding
def geocode_address(Address):
    try:
        location = geocode(Address)
        return (location.latitude, location.longitude) if location else (None, None)
    except Exception as e:
        return (None, None)

# Apply the geocoding function to the 'address' column
data['coordinates'] = data['Address'].apply(geocode_address)

# Split coordinates into 'latitude' and 'longitude' columns
data[['latitude', 'longitude']] = pd.DataFrame(data['coordinates'].tolist(), index=data.index)

# Drop the 'coordinates' column if you don't need it anymore
data.drop(columns=['coordinates'], inplace=True)

# Save the geocoded data to a new CSV file
data.to_csv("geocoded_addresses.csv", index=False)

print("Geocoding complete!")

##completly broke -- couldn't get a result
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('VASAI EASTSHOP NO 2 THAKUR HOUSE RENGE OFFICE NAKA,-1,PALGHAR,MAHARASHTRA,401208',), **{}).
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 500, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 403
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderInsufficientPrivileges: Non-successful status code 403
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('VASAI EASTSHOP NO 2 THAKUR HOUSE RENGE OFFICE NAKA,-1,PALGHAR,MAHARASHTRA,401208',), **{}).
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 500, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 403
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderInsufficientPrivileges: Non-successful status code 403
# RateLimiter swallowed an error after 2 retries. Called with (*('VASAI EASTSHOP NO 2 THAKUR HOUSE RENGE OFFICE NAKA,-1,PALGHAR,MAHARASHTRA,401208',), **{}).
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 500, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 403
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderInsufficientPrivileges: Non-successful status code 403
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('TALASARI PALGHARSHOP NO 768 A SUTRAPADA,-1,PALGHAR,MAHARASHTRA,401606',), **{}).
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#                        ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1311, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1167, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#                        ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=TALASARI+PALGHARSHOP+NO+768+A+SUTRAPADA%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401606&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=TALASARI+PALGHARSHOP+NO+768+A+SUTRAPADA%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401606&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=TALASARI+PALGHARSHOP+NO+768+A+SUTRAPADA%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401606&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('TALASARI PALGHARSHOP NO 768 A SUTRAPADA,-1,PALGHAR,MAHARASHTRA,401606',), **{}).
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#                        ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1311, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1167, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#                        ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=TALASARI+PALGHARSHOP+NO+768+A+SUTRAPADA%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401606&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=TALASARI+PALGHARSHOP+NO+768+A+SUTRAPADA%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401606&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=TALASARI+PALGHARSHOP+NO+768+A+SUTRAPADA%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401606&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter swallowed an error after 2 retries. Called with (*('TALASARI PALGHARSHOP NO 768 A SUTRAPADA,-1,PALGHAR,MAHARASHTRA,401606',), **{}).
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#                        ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1311, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1167, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#                        ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=TALASARI+PALGHARSHOP+NO+768+A+SUTRAPADA%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401606&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=TALASARI+PALGHARSHOP+NO+768+A+SUTRAPADA%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401606&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=TALASARI+PALGHARSHOP+NO+768+A+SUTRAPADA%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401606&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('POOJA BOISAR PALGHARRAHUL KIRANA STORE NAVAPUR ROAD DHODI,-1,PALGHAR,MAHARASHTRA,401501',), **{}).
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#                        ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1311, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1167, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#                        ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=POOJA+BOISAR+PALGHARRAHUL+KIRANA+STORE+NAVAPUR+ROAD+DHODI%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401501&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=POOJA+BOISAR+PALGHARRAHUL+KIRANA+STORE+NAVAPUR+ROAD+DHODI%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401501&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=POOJA+BOISAR+PALGHARRAHUL+KIRANA+STORE+NAVAPUR+ROAD+DHODI%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401501&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('POOJA BOISAR PALGHARRAHUL KIRANA STORE NAVAPUR ROAD DHODI,-1,PALGHAR,MAHARASHTRA,401501',), **{}).
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#                        ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1311, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1167, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#                        ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=POOJA+BOISAR+PALGHARRAHUL+KIRANA+STORE+NAVAPUR+ROAD+DHODI%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401501&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=POOJA+BOISAR+PALGHARRAHUL+KIRANA+STORE+NAVAPUR+ROAD+DHODI%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401501&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=POOJA+BOISAR+PALGHARRAHUL+KIRANA+STORE+NAVAPUR+ROAD+DHODI%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401501&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter swallowed an error after 2 retries. Called with (*('POOJA BOISAR PALGHARRAHUL KIRANA STORE NAVAPUR ROAD DHODI,-1,PALGHAR,MAHARASHTRA,401501',), **{}).
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#                        ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1311, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1167, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#                        ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=POOJA+BOISAR+PALGHARRAHUL+KIRANA+STORE+NAVAPUR+ROAD+DHODI%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401501&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=POOJA+BOISAR+PALGHARRAHUL+KIRANA+STORE+NAVAPUR+ROAD+DHODI%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401501&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#     ^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=POOJA+BOISAR+PALGHARRAHUL+KIRANA+STORE+NAVAPUR+ROAD+DHODI%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401501&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('BOLINJ NAKA VIRAR WEST VASAI THANESHOP NO 1 HAJIMIYA MANJIL OPP UNION BANK,-1,PALGHAR,MAHARASHTRA,401303',), **{}).
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#                        ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
# ...
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=ACHOLE+ROAD%2C+NALASOPARA+%28EAST%29KARAN+A+SHOP+NO+1-4%2C+4A%2C+5%266%2C+MAJITHIA+PARK%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401209&format=json&limit=1 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x143b6b090>: Failed to establish a new connection: [Errno 61] Connection refused'))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('W/O Room No 03 Ground Floor A Wing Vinayak Complex Ganesh Bhavan Boisar West D J Nagar Road Dandi PW/O Room No 03 Ground Floor A Wing Vinayak Complex Ganesh Bhavan Boisar West D J Nagar Road Dandi P,-1,PALGHAR,MAHARASHTRA,401501',), **{}).
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 466, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 461, in _make_request
#     httplib_response = conn.getresponse()
#                        ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 1378, in getresponse
#     response.begin()
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 318, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/http/client.py", line 279, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/socket.py", line 706, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1311, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/ssl.py", line 1167, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#                        ^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 468, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 357, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 826, in urlopen
#     return self.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py", line 798, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=W%2FO+Room+No+03+Ground+Floor+A+Wing+Vinayak+Complex+Ganesh+Bhavan+Boisar+West+D+J+Nagar+Road+Dandi+PW%2FO+Room+No+03+Ground+Floor+A+Wing+Vinayak+Complex+Ganesh+Bhavan+Boisar+West+D+J+Nagar+Road+Dandi+P%2C-1%2CPALGHAR%2CMAHARASHTRA%2C401501&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/supriya/anaconda3/lib/python3.11/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q
py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: Requests>=2.31.0 in ./anaconda3/lib/python3.11/site-packages (from opencage) (2.31.0)
# Collecting backoff>=2.2.1 (from opencage)
#   Obtaining dependency information for backoff>=2.2.1 from https://files.pythonhosted.org/packages/df/73/b6e24bd22e6720ca8ee9a85a0c4a2971af8497d8f3193fa05390cbd46e09/backoff-2.2.1-py3-none-any.whl.metadata
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting tqdm>=4.66.4 (from opencage)
#   Obtaining dependency information for tqdm>=4.66.4 from https://files.pythonhosted.org/packages/48/5d/acf5905c36149bbaec41ccf7f2b68814647347b72075ac0b1fe3022fdc73/tqdm-4.66.5-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.6 MB/s eta 0:00:00
# Collecting certifi>=2024.07.04 (from opencage)
#   Obtaining dependency information for certifi>=2024.07.04 from https://files.pythonhosted.org/packages/12/90/3c9ff0512038035f59d279fddeb79f5f1eccd8859f06d6163c58798b9487/certifi-2024.8.30-py3-none-any.whl.metadata
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting aiohttp>=3.10.5 (from opencage)
#   Obtaining dependency information for aiohttp>=3.10.5 from https://files.pythonhosted.org/packages/07/4f/767387b39990e1ee9aba8ce642abcc286d84d06e068dc167dab983898f18/aiohttp-3.10.5-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading aiohttp-3.10.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp>=3.10.5->opencage)
#   Obtaining dependency information for aiohappyeyeballs>=2.3.0 from https://files.pythonhosted.org/packages/18/b6/58ea188899950d759a837f9a58b2aee1d1a380ea4d6211ce9b1823748851/aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in ./anaconda3/lib/python3.11/site-packages (from aiohttp>=3.10.5->opencage) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in ./anaconda3/lib/python3.11/site-packages (from aiohttp>=3.10.5->opencage) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./anaconda3/lib/python3.11/site-packages (from aiohttp>=3.10.5->opencage) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./anaconda3/lib/python3.11/site-packages (from aiohttp>=3.10.5->opencage) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./anaconda3/lib/python3.11/site-packages (from aiohttp>=3.10.5->opencage) (1.8.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.11/site-packages (from Requests>=2.31.0->opencage) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.11/site-packages (from Requests>=2.31.0->opencage) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./anaconda3/lib/python3.11/site-packages (from Requests>=2.31.0->opencage) (1.26.16)
# Downloading opencage-3.0.2-py3-none-any.whl (21 kB)
# Downloading aiohttp-3.10.5-cp311-cp311-macosx_11_0_arm64.whl (388 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.0/389.0 kB 5.3 MB/s eta 0:00:00a 0:00:01
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.3/167.3 kB 4.2 MB/s eta 0:00:0000:01
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 5.0 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Installing collected packages: tqdm, certifi, backoff, aiohappyeyeballs, aiohttp, opencage
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.5
#     Uninstalling aiohttp-3.8.5:
#       Successfully uninstalled aiohttp-3.8.5
# Successfully installed aiohappyeyeballs-2.4.0 aiohttp-3.10.5 backoff-2.2.1 certifi-2024.8.30 opencage-3.0.2 tqdm-4.66.5

# %%
###With opencage API

import pandas as pd
from opencage.geocoder import OpenCageGeocode
import time
import os

# Replace 'your_api_key' with your actual OpenCage API key
API_KEY = '9235c10eeeb945b69d0b979d0ba8bd63'
geocoder = OpenCageGeocode(API_KEY)

# Function to geocode an address using OpenCage
def geocode_Address(Address):
    try:
        result = geocoder.geocode(Address, no_annotations='1')
        if result and len(result):
            # Extract the first result's latitude and longitude
            return result[0]['geometry']['lat'], result[0]['geometry']['lng']
        else:
            return None, None
    except Exception as e:
        print(f"Error geocoding {Address}: {e}")
        return None, None

# Load dataset
input_file = '/Users/supriya/Downloads/Banking Export Data CSV-5.csv'
output_file = '/Users/Supriya/Downloads/geocoded_addresses.csv'

# Check if the output file already exists (if the process was previously started)
if os.path.exists(output_file):
    # Load the existing geocoded data
    df = pd.read_csv(output_file)
    print(f"Resuming from existing file {output_file}...")
else:
    # If the file doesn't exist, load the original dataset and create new columns
    df = pd.read_csv(input_file)
    df['latitude'] = None
    df['longitude'] = None

# Geocode each address that hasn't been geocoded yet
for index, row in df.iterrows():
    if pd.isna(row['latitude']) or pd.isna(row['longitude']):
        Address = row['Address']
        lat, lng = geocode_Address(Address)

        # Store the results in the dataframe
        df.at[index, 'latitude'] = lat
        df.at[index, 'longitude'] = lng

        # Print progress
        print(f"Geocoded {Address}: {lat}, {lng}")

        # Save after each iteration to avoid data loss
        df.to_csv(output_file, index=False)

        # Respect the rate limit (typically 1 request per second)
        time.sleep(1)  # 1-second delay

print("Geocoding complete. Data saved to geocoded_addresses.csv")


###Slower and higher Nulls (~50%). 2500 entries are free
# Out:
# Geocoded SHAHAPUR ROAD AT SHIRISHPADA PO KONE TAL WADA DIST PALGHAR (THANE)SHAHAPUR ROAD AT SHIRISHPADA PO KONE TAL WADA DIST PALGHAR (THANE),-1,PALGHAR,MAHARASHTRA,421303: None, None
# Geocoded SONAR ALI SAMBHAJI PATH AT POST JAWHAR (RURAL)THANE 27SONAR ALI SAMBHAJI PATH AT POST JAWHAR (RURAL)THANE 27,-1,PALGHAR,MAHARASHTRA,401603: None, None
# Geocoded SHOP NO 6 CHNCH PADAAAZAD NAGAR GOKHIVRE VASAI EASTSHOP NO 6 CHNCH PADAAAZAD NAGAR GOKHIVRE VASAI EAST7,-1,PALGHAR,MAHARASHTRA,401208: None, None
# Geocoded 203 GODAVARI APT JAVHAR RD NR 3RD PETROL PUMP RAMWADI DAHANU ROAD E THANE 27203 GODAVARI APT JAVHAR RD NR 3RD PETROL PUMP RAMWADI DAHANU ROAD E THANE 27,-1,PALGHAR,MAHARASHTRA,401406: None, None
# Geocoded AT PIMPALGAON AT PIMPALGAON 27AT PIMPALGAON AT PIMPALGAON 27,-1,PALGHAR,MAHARASHTRA,401603: 47.27541, 8.4897
# Geocoded VIRARSWAMI SAMATHA APARTMENT PATANKAR PARK NALLASOPAPA WEST,-1,PALGHAR,MAHARASHTRA,401203: 19.69693, 72.76543
# Geocoded PALGHARSHOP NO 26 JIVDANI PLAZA BH SBI SHOP NO 26 JIVDANI PLAZA BH SBI,-1,PALGHAR,MAHARASHTRA,401305: 15.35, 107.16667
# Geocoded PALGHARSHOP NO G 09 CHARNIYA TOWER NO 2 PATIL PADA TAL TALASHRI,-1,PALGHAR,MAHARASHTRA,401606: None, None
# Geocoded DAHANU ROAD1ST FLOOR,KUMAR CORNER,NR-JILA PARISAD,-1,PALGHAR,MAHARASHTRA,401602: 19.69693, 72.76543
# Geocoded WADA PALGHARAT POST MANDE,-1,PALGHAR,MAHARASHTRA,401404: 19.6969, 72.7654
# Geocoded TAL JAWHAR DIST PALGHARAT POST DENGACHIMET,-1,PALGHAR,MAHARASHTRA,401603: 19.9095, 72.8126
# Geocoded JAWHAR PALGHARAT POST SAKUR,-1,PALGHAR,MAHARASHTRA,421603: 19.3526, 73.9077
# Geocoded TAL VADA DIST PALGHARAT POST KALAMKHAND,-1,PALGHAR,MAHARASHTRA,421303: 18.5167, 73.5167
# Geocoded TAL JAWHAR, PALGHARCHAMBHARSHET,-1,PALGHAR,MAHARASHTRA,401503: 19.8746, 72.6851
# Geocoded SIDDHI SOFFY COMPLEX,CHINCHGHAR RD,KUDUS SIDDHI SOFFY COMPLEX,CHINCHGHAR RD,KUDUS 27SHRINIL HARIMAN JADHAV,-1,PALGHAR,MAHARASHTRA,401404: None, None
# Geocoded SHOP-01,PATILPADA, UDHAVA ROAD SHOP-01,PATILPADA, UDHAVA ROAD 27SHOP-01,PATILPADA, UDHAVA ROAD SHOP-01,PATILPADA, UDHAVA ROAD 27,-1,PALGHAR,MAHARASHTRA,401606: 53.35222, -7.20167
# Geocoded PALGHARSHOP-3 GANESHASHISH BUILDING PALGHAR,-1,PALGHAR,MAHARASHTRA,401404: 19.6969, 72.7654
# Geocoded THANETAL-VADA,DIST-THANE,-1,PALGHAR,MAHARASHTRA,421303: 18.5167, 73.5167
# Geocoded WADAAT POST AAINSHET WADA AT POST AAINSHET WADA,-1,PALGHAR,MAHARASHTRA,401404: 19.69693, 72.76543
# Geocoded VASAIMICKY PALACE GURUNANAK NAGAR SHOP NO 2 NEAR SBI BRANCH VASAI,-1,PALGHAR,MAHARASHTRA,401202: None, None
# Geocoded VASAI ROAD  W  BRANCH, DISTRICT: THANE.SHOP NO 10 SAI CHAYYA APT GALA NAGAR ACHOLE ROAD,-1,PALGHAR,MAHARASHTRA,401202: 43.88333, 5.4
# Geocoded PalgharNEW SWATI PLACE SUYOG NAGAR BHABOLA CHULNA RD VASAI ROAD,-1,PALGHAR,MAHARASHTRA,401202: 19.38331, 72.83106
# Geocoded PALGHARGOKHIVARE VASAI EAST,-1,PALGHAR,MAHARASHTRA,401208: 19.3547, 72.9094
# Geocoded VASAI EAST PALGHAREVERSHINE NAGAR,-1,PALGHAR,MAHARASHTRA,401209: 20.1171, 73.2565
# Geocoded PALGHAR THANEWADOLI JAWHAR,-1,PALGHAR,MAHARASHTRA,401603: 19.9095, 72.8126
# Geocoded THANEVASAI WEST,-1,PALGHAR,MAHARASHTRA,401202: 20.1171, 73.2565
# Geocoded NR TRANSFORMER BOISAR EAST PALGHARSHOP NO.6943 YADAV NAGAR,-1,PALGHAR,MAHARASHTRA,401501: 19.69693, 72.76543
# Geocoded THANEVIRAR WEST VASAI,-1,PALGHAR,MAHARASHTRA,401303: 20.5196, 73.0973
# Geocoded SATIVALI VASAI EAST THANESAMTA NAGAR MORYA NAKA,-1,PALGHAR,MAHARASHTRA,401208: 19.69693, 72.76543
# Geocoded GURUDATTA NAGAR COMPLEX,PHULPADA,SHOP NO 3,AVDHOOT ,SHRI,-1,PALGHAR,MAHARASHTRA,401305: 47.27541, 8.4897
# Geocoded YASHWANT GAURAV COMPLECSHOP NO 4,SHREE SAI HEIGHTS,,-1,PALGHAR,MAHARASHTRA,401203: 19.69693, 72.76543
# Geocoded DONTALAV ROAD, VIRAR WEST PALGHARNEAR RIDE ONE E MOTORS UMBERGAOTHAN NAKA,-1,PALGHAR,MAHARASHTRA,401301: None, None
# Geocoded WAKANPADA,SHOP 2,CHAUDHARY COMPOUND,,-1,PALGHAR,MAHARASHTRA,401209: 20.1171, 73.2565
# Geocoded COURT RD,SHOP NO 7, SURATWALA COMPLEX.,-1,PALGHAR,MAHARASHTRA,401201: 19.69693, 72.76543
# Geocoded YADAV NGR,SHOP 3,NARAYAN SHOPPING CENTRE,,-1,PALGHAR,MAHARASHTRA,401501: 19.69693, 72.76543
# Geocoded NEAR MARATHI SCHOOL VALIV GAON VASAI ESHOP NO 3 BHAGYLAXMI APARTMENT,-1,PALGHAR,MAHARASHTRA,401208: None, None
# Geocoded SHIGAON ROAD,KRISHAN NAGAR,,-1,PALGHAR,MAHARASHTRA,401501: 18.0677, 73.7348
# Geocoded GAURAI PADA,ANNA DISH COMPOUND,SHOP 5, MUNNA SINGH CHAWL,,-1,PALGHAR,MAHARASHTRA,401209: 19.69693, 72.76543
# Geocoded EVERSHINE CITY,A/P VASAI EAST,,-1,PALGHAR,MAHARASHTRA,401208: 19.3547, 72.9094
# Geocoded BOISAR,NR RLY PFATAK,3402, SHREERAM NAGAR,SHIGAON RD,,-1,PALGHAR,MAHARASHTRA,401501: 47.27541, 8.4897
# Geocoded BHAJI MARKET,AT POST VADA,,-1,PALGHAR,MAHARASHTRA,421303: 18.5167, 73.5167
# Geocoded NR GANESH MANDIR,ANAS,ASNAS,PALSAI GANESHPURI RD,,-1,PALGHAR,MAHARASHTRA,421312: 19.69693, 72.76543
# Geocoded NEAR MANASVI COMPUTERS,AT POST KASA, SHIV MANDIR,,-1,PALGHAR,MAHARASHTRA,401602: None, None
# Geocoded BOISAR ,GANESH NAGAR, RANISHIGAV RD,,-1,PALGHAR,MAHARASHTRA,401501: 18.0677, 73.7348
# Geocoded SANTOSH BHAVAN NALASOPARA EAST PALGHARSHOP NO 07 OM SAI NAGAR GAURAI NAKA,-1,PALGHAR,MAHARASHTRA,401209: 27.42397, 77.09922
# Geocoded CONGRESS HOUSE, PARNAKA VASAI (WEST),P.B.NO.1,VASAI,-1,PALGHAR,MAHARASHTRA,401201: 20.1171, 73.2565
# Geocoded dahanuP.B.NO.1,DAHANU ROAD,DAHANU,-1,PALGHAR,MAHARASHTRA,401602: 18.5167, 73.5167
# Geocoded palgharMAHIM ROAD,PALGHAR,-1,PALGHAR,MAHARASHTRA,401404: 19.6969, 72.7654
# Geocoded jawaharJAWAHAR,-1,PALGHAR,MAHARASHTRA,401603: 19.9095, 72.8126
# Geocoded wadaWADA,-1,PALGHAR,MAHARASHTRA,421303: 18.5167, 73.5167
# Geocoded MUMBAINO.2,BASSEIN ROAD,VASAI,P.O.NAVGHAR,401202,-1,PALGHAR,MAHARASHTRA,401202: 20.1171, 73.2565
# Geocoded boisar westPLOT NO,H-1,TARAPUR INDUSTRIL AREA,TARAPUR-401501,-1,PALGHAR,MAHARASHTRA,401501: 18.0677, 73.7348
# Geocoded MUMBAISANKALP,VIRAR AGASHI ROAD,VIRAR-401303,BASSEIN TEH.,-1,PALGHAR,MAHARASHTRA,401303: 19.69693, 72.76543
# Geocoded talasariTALASARI-401606,-1,PALGHAR,MAHARASHTRA,401606: 21.5825, 74.4797
# Geocoded VASAI EASTBASSIEN TAL.IND.EST.BR,AT-ACHOLE,PO-GOKHIVARE,TQ-BASSIEN,-1,PALGHAR,MAHARASHTRA,401208: 47.27541, 8.4897
# Geocoded wadaGORHE,TEH.WADA,-1,PALGHAR,MAHARASHTRA,421303: 18.5167, 73.5167
# Geocoded Near Patankar ParkBharati Apartment, Building A Nalasopara West,-1,PALGHAR,MAHARASHTRA,401203: None, None
# Geocoded TAPS 3 & 4NPCIL, TMS TARAPUR BOISAR, TALUKA PALGHAR,-1,PALGHAR,MAHARASHTRA,401504: 19.69693, 72.76543
# Geocoded MANVELPADA ROADSHOP NO. 1,2,3, GROUND FLR., MOHAK PLAZA VIRAR,-1,PALGHAR,MAHARASHTRA,401305: 43.14322, -2.96204
# Geocoded ACHOLE ROADGROUND FLOOR, AKANKSHA TOWER THANE,-1,PALGHAR,MAHARASHTRA,401209: 20.1171, 73.2565
# Geocoded TANDULWADI ROAD,1ST FLOOR, RADHACHANDRA HERITAGE, PALGHAR,-1,PALGHAR,MAHARASHTRA,401102: 19.69693, 72.76543
# Geocoded NALASOPARA HIGHWAY,BHAU NIVAS,HOUSENO.343, BILALPADA,-1,PALGHAR,MAHARASHTRA,401208: 19.3547, 72.9094
# Geocoded BARI WADA,OM SAI BAUG, HOUSE NO.1025, DHAKATI DAHANU,-1,PALGHAR,MAHARASHTRA,401601: 47.27541, 8.4897
# Geocoded MAHIM BAZAR PALGHAR TOMMAHIM BAZAR PALGHAR TOM,-1,PALGHAR,MAHARASHTRA,401402: 19.69693, 72.76543
# Geocoded SHIVAJI NAGAR BOISAR TOMSHIVAJI NAGAR BOISAR TOM,-1,PALGHAR,MAHARASHTRA,401504: 19.69693, 72.76543
# Geocoded GANESH NAGAR BOISAR TOMGANESH NAGAR BOISAR TOM,-1,PALGHAR,MAHARASHTRA,401504: 19.69693, 72.76543
# Geocoded NAVLI PHATAK PALGHAR TOMNAVLI PHATAK PALGHAR TOMNAVLI PHATAK PALGHAR TOM,-1,PALGHAR,MAHARASHTRA,401404: 16.77348, -3.00742
# Geocoded SANTOSH BHAVAN NALLASOPARSANTOSH BHAVAN NALLASOPAR,-1,PALGHAR,MAHARASHTRA,401203: 21.5807, 74.0594
# Geocoded KHARVATE PADA NALLASOPARAKHARVATE PADA NALLASOPARA,-1,PALGHAR,MAHARASHTRA,401203: 21.5807, 74.0594
# Geocoded NANA NANI PARK VIRAR TOMNANA NANI PARK VIRAR TOM,-1,PALGHAR,MAHARASHTRA,401305: 47.27541, 8.4897
# Geocoded GLOBAL CITY VIRAR TOMGLOBAL CITY VIRAR TOM,-1,PALGHAR,MAHARASHTRA,401303: 20.5196, 73.0973
# Geocoded NAVAPUR RD BOISAR TOMNAVAPUR RD BOISAR TOM,-1,PALGHAR,MAHARASHTRA,401501: 19.69693, 72.76543
# Geocoded PREMA NIVAS WALIV TOMPREMA NIVAS WALIV TOM,-1,PALGHAR,MAHARASHTRA,401208: 19.69693, 72.76543
# Geocoded CHHEDA NAGAR, NALLASOPARA WESTSHOP NO 3, GAURAV GARDEN, NEAR MANTHAN HOTEL,-1,PALGHAR,MAHARASHTRA,401303: None, None
# Geocoded NECT TO RAM BALRAM BLGD., NALLASOPARA EASTSHOP NO 02, SADGURU BHAVAN CHAWL, AMBAWADI,,-1,PALGHAR,MAHARASHTRA,401209: None, None
# Geocoded NEAR CARNIVAL CINEMA, EVERSHINE CITY, VASAI EASTSHOP NO 9, SAI ASHISH TOWER,,-1,PALGHAR,MAHARASHTRA,401208: None, None
# Geocoded SRI RAM NAGAR NAKA, PELHAR RD, NALLASOPARA EASTSHOP NO1, JEEDHANI DARSHAN BLDG.,,-1,PALGHAR,MAHARASHTRA,401209: None, None
# Geocoded SRI RAM NAGAR NAKA, PELHAR RD, NALLASOPARA EASTSHOP NO1, JEEDHANI DARSHAN BLDG.,,-1,PALGHAR,MAHARASHTRA,401209: None, None
# Geocoded wadaWADA,-1,PALGHAR,MAHARASHTRA,421303: 18.5167, 73.5167
# Geocoded ACHOLE ROADGROUND FLOOR, AKANKSHA TOWER THANE,-1,PALGHAR,MAHARASHTRA,401209: 20.1171, 73.2565
# Geocoded PALGHARAT & POST WADA TALUKA WADA,-1,PALGHAR,MAHARASHTRA,421303: 18.5167, 73.5167
# Geocoded BOISORSHIGAON ROAD,-1,PALGHAR,MAHARASHTRA,401501: 18.0677, 73.7348
# Geocoded BOISARYESHWANT SHRUSHTI,-1,PALGHAR,MAHARASHTRA,401501: 18.0677, 73.7348
# Geocoded DAHANUA J AUTO PETROL PUMP,-1,PALGHAR,MAHARASHTRA,401602: 18.5167, 73.5167
# Geocoded DAHANUCHINCHNI,-1,PALGHAR,MAHARASHTRA,401601: 19.9678, 72.7126
# Geocoded PALGHARNPCIL TARAPUR,-1,PALGHAR,MAHARASHTRA,401502: 19.7986, 73.094
# Geocoded Tarapur RoadBARC Colony Gate Boisar,-1,PALGHAR,MAHARASHTRA,401501: 18.0677, 73.7348
# Geocoded GROUND FLOOR, GM HEIGHTSSHOP NO 4,,-1,PALGHAR,MAHARASHTRA,401303: 20.5196, 73.0973
# Geocoded BOISARSHOP NO 8, OPP. VITTHAL MANDIR, AT POST UMROLI,,-1,PALGHAR,MAHARASHTRA,401404: 47.27541, 8.4897
# Geocoded TARAPUR BUS STOP BOISAR TOMSHOP NO 4 AT POST TARAPUR,-1,PALGHAR,MAHARASHTRA,401502: 19.86499, 72.68426
# Geocoded ROYAL CLASSIC, BETEGAON, BOISAR ROADshop No.32 to 41,-1,PALGHAR,MAHARASHTRA,401501: 19.69693, 72.76543
# Geocoded boisar westPLOT NO,H-1,TARAPUR INDUSTRIL AREA,TARAPUR-401501,-1,PALGHAR,MAHARASHTRA,401501: 18.0677, 73.7348
# Geocoded palgharMAHIM ROAD,PALGHAR,-1,PALGHAR,MAHARASHTRA,401404: 19.6969, 72.7654
# Geocoded wadaWADA,-1,PALGHAR,MAHARASHTRA,421303: 18.5167, 73.5167
# Geocoded jawaharJAWAHAR,-1,PALGHAR,MAHARASHTRA,401603: 19.9095, 72.8126
# Geocoded dahanuP.B.NO.1,DAHANU ROAD,DAHANU,-1,PALGHAR,MAHARASHTRA,401602: 18.5167, 73.5167
# Geocoded CONGRESS HOUSE, PARNAKA VASAI (WEST),P.B.NO.1,VASAI,-1,PALGHAR,MAHARASHTRA,401201: 20.1171, 73.2565
# Geocoded ACHOLE ROADGROUND FLOOR, AKANKSHA TOWER THANE,-1,PALGHAR,MAHARASHTRA,401209: 20.1171, 73.2565
# Geocoded BOISAR WESTKHODARAM BAG,-1,PALGHAR,MAHARASHTRA,401501: 18.0677, 73.7348
# Geocoded Parnaka, Vasai (West), Palghar,Congress House, Annasaheb Vartak Sabhagruh & Trust,,-1,PALGHAR,MAHARASHTRA,401201: 47.27541, 8.4897
# Geocoded NEAR ST DEPOT,BOISAR, PALGHARPALGHARSHIVAKALAN ARCADE,,-1,PALGHAR,MAHARASHTRA,401501: None, None
# Geocoded WADEVada Shahapur Road, Abitghar Wada, Thane, Maharashtra MH MUMBA,-1,PALGHAR,MAHARASHTRA,421303: 47.27541, 8.4897
# Geocoded VASAI-VIRAR CITY M CORPChinchpada Near Shivsena Office Gokhiware Vasai East Palghar MH VASAI,-1,PALGHAR,MAHARASHTRA,401202: None, None
# Geocoded PALGHARSONA GUPTA CHAWL KARGIL ROAD NALLASOPARA VASAI PALGHAR MH NAGPU,-1,PALGHAR,MAHARASHTRA,401209: None, None
# Geocoded Vangaon, plaghar, Maharashtra MH DAHANpatilpada, Dhanu,-1,PALGHAR,MAHARASHTRA,401103: 19.8762, 72.7627
# Geocoded Palghar MH THANEChainchani dahanu,-1,PALGHAR,MAHARASHTRA,401601: 19.9678, 72.7126
# Geocoded ROAD MOKHADA POST MOKHADA DIST PALGHAR 401604 MAHARASHTRA MH PARAH478 MAIN,-1,PALGHAR,MAHARASHTRA,401604: 31.40984, 35.13235
# Geocoded NALASOPARA EAST, PALGHAR MH VASAIRAJHANS COMPLEX,-1,PALGHAR,MAHARASHTRA,401209: 20.1171, 73.2565
# Geocoded ROAD, VASAI EAST MH VASAIWAGHRALPADA RAJAVALI,-1,PALGHAR,MAHARASHTRA,401202: 20.1171, 73.2565
# Geocoded and Multicentre At Naka Dahanu Palghar Maharashtra MH PARBHNV Xerox,-1,PALGHAR,MAHARASHTRA,401602: None, None
# Geocoded PALGHAR MH DAHANVANGAON DAHANU,-1,PALGHAR,MAHARASHTRA,401103: 19.8762, 72.7627
# Geocoded Nagar Palghar Boisar,Maharashtra MH BOISAShivam Niwas,Ganesh,-1,PALGHAR,MAHARASHTRA,401501: 19.69693, 72.76543
# Geocoded Near Dhyan Mandir Nalsopara West , Palghar MH VASAIPanchal Nagar,,-1,PALGHAR,MAHARASHTRA,401209: None, None
# Geocoded MOKHADA MH THANEGONDE BK,-1,PALGHAR,MAHARASHTRA,401604: 19.9365, 73.3403
# Geocoded Station Dahanu Palghar Maharashtra MH DAHANVangaon Railway,-1,PALGHAR,MAHARASHTRA,401103: 19.69693, 72.76543
# Geocoded BOISAR WEST TARAPUR ROAD, BOISAR WEST MH BOISATARAPUR ROAD,,-1,PALGHAR,MAHARASHTRA,401501: 47.27541, 8.4897
# Geocoded SOCIETY CHAWL SHRIMIK NAGAR NALASOPARA EAST MH VASAIMAHALAXMI WALFARE,-1,PALGHAR,MAHARASHTRA,401209: 47.27541, 8.4897
# Geocoded APARTMENT VIRAR EAST PALGHAR 401305 MH THANEJAYSHRI SAI,-1,PALGHAR,MAHARASHTRA,401303: 19.69693, 72.76543
# Geocoded HAMRAPUR TQ WADA DIST PALGHAR MH MUMBAHAMRAPUR PHATA,-1,PALGHAR,MAHARASHTRA,401404: 19.69693, 72.76543
# Geocoded KASA DAHANU PALGHAR MH DAHANSIDDHI COMPLEX,-1,PALGHAR,MAHARASHTRA,401602: 18.5167, 73.5167
# Geocoded UMROLI BIRWADI POST UMROLI MH DAHANBIRWADI POST,-1,PALGHAR,MAHARASHTRA,401501: 19.69693, 72.76543
# Geocoded GRAMPANCHAYAT TEMBHODE NEAR GRAMPANCHAYAT MH PARAHTEMBHODE NEAR,-1,PALGHAR,MAHARASHTRA,401404: None, None
# Geocoded 5 BRAMHA APARTMENT MANVELPADA MH VASAISHOP NO,-1,PALGHAR,MAHARASHTRA,401305: 19.69693, 72.76543
# Geocoded APARTMENT SITARA BAKERY RD ANSARI NAGAR NALASOPARA EAST MH VASAIAL KHADIZA,-1,PALGHAR,MAHARASHTRA,401305: None, None
# Geocoded MH WADALVikramgad Maharashtra,-1,PALGHAR,MAHARASHTRA,421303: 18.5167, 73.5167
# Geocoded Talasari Talasari, Palghar, MaharashtraBorigaon, Borigaon,,-1,PALGHAR,MAHARASHTRA,401701: 20.1157, 72.7388
# Geocoded Park Palghar,MaharashtraGround Floor,Kamat,-1,PALGHAR,MAHARASHTRA,401303: 20.5196, 73.0973
# Geocoded Palghar MaharashtraPAM TEMBHI,-1,PALGHAR,MAHARASHTRA,401501: 18.0677, 73.7348
# Geocoded Palghar MaharashtraPalghar Maharashtra,-1,PALGHAR,MAHARASHTRA,401701: 20.1157, 72.7388
# Geocoded Road, Jambhul Pada Pachchhapur,Bhiwandi, ThaneAmbadi Kandili,-1,PALGHAR,MAHARASHTRA,421101: 19.69693, 72.76543
# Geocoded NALLASOPARA EASTNALLASOPARA EAST,-1,PALGHAR,MAHARASHTRA,401305: 19.9922, 73.202
# Geocoded Palghar, Maharashtrakoshimshet, Dolhara,-1,PALGHAR,MAHARASHTRA,401604: 19.9365, 73.3403
# Geocoded Palghar Palghar, MaharashtraBeriste Mokhada,-1,PALGHAR,MAHARASHTRA,401604: 19.9365, 73.3403
# Geocoded Palghar MH THANEVadakti Pada,-1,PALGHAR,MAHARASHTRA,401602: 18.5167, 73.5167
# Geocoded Wakan Pada, Vasai MH THANERafique Compound,-1,PALGHAR,MAHARASHTRA,401208: 19.3547, 72.9094
# Geocoded MOREGAON, NALASOPARA EAST MH THANEJIJAI NAGAR,-1,PALGHAR,MAHARASHTRA,401209: 20.1171, 73.2565
# Geocoded Maharashtra MH MUMBAAse Palghar,-1,PALGHAR,MAHARASHTRA,401604: 19.9365, 73.3403
# Geocoded Ase, Palghar Maharashtra MH MUMBASwaminagar Tal,-1,PALGHAR,MAHARASHTRA,401604: 19.9365, 73.3403
# Geocoded Dahanu Palghar Maharashtra MH DAHANToranpada Vangaon,-1,PALGHAR,MAHARASHTRA,401103: 19.8762, 72.7627
# Geocoded MH BOISASantoshi Palghar,-1,PALGHAR,MAHARASHTRA,401501: 18.0677, 73.7348
# Geocoded Palghar, Maharashtra MH PANDHjangalpada walvanda,-1,PALGHAR,MAHARASHTRA,401603: 19.9095, 72.8126
# Geocoded bhabola chulna road Vasai West MH MUMBAsuyog Nagar,,-1,PALGHAR,MAHARASHTRA,401202: 19.69693, 72.76543
# Geocoded Maharashtra MH THANEUmberpada Palghar,-1,PALGHAR,MAHARASHTRA,401604: 19.9365, 73.3403
# Geocoded Palghar Maharashtra MH BHITHDhamani Mokhada,-1,PALGHAR,MAHARASHTRA,401604: 19.9365, 73.3403
# Geocoded Maharashtra MH PARBHDahanu Palghar,-1,PALGHAR,MAHARASHTRA,401602: 18.5167, 73.5167
# Geocoded Wada MH PALGABhoir Kalamkhand,,-1,PALGHAR,MAHARASHTRA,421303: 18.5167, 73.5167
# Geocoded Kaner Palghar MH PALGAVirar Fata,-1,PALGHAR,MAHARASHTRA,401303: 20.5196, 73.0973
# Geocoded WEST MAKANE PALHHAR MAHARASHTRA MH WADALKENDRA SAPHALE,-1,PALGHAR,MAHARASHTRA,401102: 19.69693, 72.76543
# Geocoded Nagar Tembhode, Palghar MH VASAIDapoli, Ambedkar,-1,PALGHAR,MAHARASHTRA,401404: 19.6969, 72.7654
# Geocoded MH MUMBAGovade Plaghar,-1,PALGHAR,MAHARASHTRA,401404: 19.6969, 72.7654
# Geocoded Palghar MH PALGAVadavali talasari,-1,PALGHAR,MAHARASHTRA,401606: 21.5825, 74.4797
# Geocoded NEAR VIDYA VIHAR SCHOOL, VIRAR WESTGROUND FLOOR, BUILDING NO 4, DESAI HOUSE,,-1,PALGHAR,MAHARASHTRA,401303: None, None
# Geocoded SHALINI SHANTHARAM SHOPPIN  PADGHESHOP NO. 3,4,7,8,-1,PALGHAR,MAHARASHTRA,421101: 47.27541, 8.4897
# Geocoded RANGE OFFICE, GOLANI NAKASHOP NO.11-13, DOMS COMPLEX, OPPOSITE PLATINUM HOSPITAL,-1,PALGHAR,MAHARASHTRA,401208: 59.01306, -161.81639
# Geocoded SUTARPADA TALASARICHARNIYA TOWER, GALA NO 1 TO 5 & 8,-1,PALGHAR,MAHARASHTRA,401606: 47.27541, 8.4897
# Geocoded PALGHARMANOR ROAD,,-1,PALGHAR,MAHARASHTRA,401404: 19.6969, 72.7654
# Geocoded CHINCHANIVANGAON NAKA, AT & POST CHINCHANI,-1,PALGHAR,MAHARASHTRA,401503: 19.8746, 72.6851
# Geocoded DISTRICT:- PALGHARAT & PO:- MOKHADA, VIA JAWAHAR, TALUKA:- MOKHADA,-1,PALGHAR,MAHARASHTRA,401604: 19.69693, 72.76543
# Geocoded POST:- UMBARPADA, SAPHALA EAST1st FLOOR, DEVBHOOMI COMPLEX,-1,PALGHAR,MAHARASHTRA,401102: 19.69693, 72.76543
# Geocoded STATION ROAD, VANGAON WESTTARE HOUSE, NEAR RAILWAY STATION,-1,PALGHAR,MAHARASHTRA,401103: None, None
# Geocoded At & Post ASE, Taluka - Mokhada882/1043, GRAM PANCHAYAT OFFICE,-1,PALGHAR,MAHARASHTRA,401604: 47.27541, 8.4897
# Geocoded PALGHAR BOISAR ROAD, SARAVALIGROUND FLOOR, GEETA MANSION,,-1,PALGHAR,MAHARASHTRA,401501: 19.69693, 72.76543
# Geocoded BOISAR ROAD UMROLIAT PO UMROLI NEAR MARATHI SCHOOL,-1,PALGHAR,MAHARASHTRA,401501: None, None
# Geocoded AT AND POST BORDI,TAL.DAHANUNO.442 ,JAIHIND CHOWK,-1,PALGHAR,MAHARASHTRA,401701: 19.69693, 72.76543
# Geocoded ZENDA CHOWK,AT & POST:- GHOLWAD,-1,PALGHAR,MAHARASHTRA,401702: 20.0847, 72.7289
# Geocoded MAIN ROAD, DAHANUFATIMA BUILDING, MASOLI,,-1,PALGHAR,MAHARASHTRA,401602: 18.5167, 73.5167
# Geocoded NAVGHAR ROAD, SAMARTH KRUPA NAGAR, VASAI EASTGAURI APARTMENT, AMBICA COMMERICAL COMPLEX,-1,PALGHAR,MAHARASHTRA,401208: None, None
# Geocoded LAKSHMIBEN CHHEDA NAGARSHOP NO 3 DHANANJAY AVENUE, PATANKAR PARK,-1,PALGHAR,MAHARASHTRA,401203: 47.27541, 8.4897
# Geocoded SARASWATI BAUG, VIVA COLLEGE ROAD, VIRAR WESTGROUND FLOOR, SHOP NO.3/11, SUYASH BUILDING,-1,PALGHAR,MAHARASHTRA,401303: 62.0, 10.0
# Geocoded AMBADI ROAD CORNER, VASAI WESTSHOP NO 7-9, HIRA NIKETAN,,-1,PALGHAR,MAHARASHTRA,401202: 19.69693, 72.76543
# Geocoded TARAPUR ROADSHOP NO. 3 TO 10, KHODARAOM BAUG,,-1,PALGHAR,MAHARASHTRA,401501: 19.69693, 72.76543
# Geocoded ACHOLE ROAD, NALASOPARA (EAST)KARAN A SHOP NO 1-4, 4A, 5&6, MAJITHIA PARK,-1,PALGHAR,MAHARASHTRA,401209: 39.11251, -100.35875
# Geocoded MAHIM ROAD, PALGHARGOKULDHAM SHOPPING CENTRE,,-1,PALGHAR,MAHARASHTRA,401404: 19.6969, 72.7654
# Geocoded MANVEL PADA, VIRAR EASTGROUND FLOOR, VIDYA SADAN,-1,PALGHAR,MAHARASHTRA,401305: 19.69693, 72.76543
# Geocoded MAHATMA GANDHI ROAD, VASAI WESTTHOMAS BAPTISTA COLLEGE CAMPUS, NEAR PAPADI CHURCH,-1,PALGHAR,MAHARASHTRA,401201: None, None
# Geocoded SWASTIK PARK, SAPHALE EASTGALA NO 1-5, GROUND FLOOR, SANGAM BUILDING,,-1,PALGHAR,MAHARASHTRA,401102: 19.69693, 72.76543
# Geocoded CHIKHALEAT & POST - CHIKHALE, NEAR HANUMAN MANDIR,-1,PALGHAR,MAHARASHTRA,401602: None, None
# Geocoded JUCHANDRA ROAD, NAIGAON EASTGROUND FLOOR, SHRI LAXMI PLAZA BUILDING,,-1,PALGHAR,MAHARASHTRA,401208: 47.27541, 8.4897
# Geocoded NEAR POLICE STATIONJIVHALA BUNGLOW,,-1,PALGHAR,MAHARASHTRA,401402: None, None
# Geocoded MAIN ROAD, OPPOSITE KAILAS THEATRE, WADAGROUND FLOOR, DAHE SOCIETY, TDCC BANK BUILDING,,-1,PALGHAR,MAHARASHTRA,421303: None, None
# Geocoded AT & POST MASWAN, ISTRICT:- PALGHARHOUSE NO 223,,-1,PALGHAR,MAHARASHTRA,401404: 19.69693, 72.76543
# Geocoded CHIKHALEAT & POST - CHIKHALE, NEAR HANUMAN MANDIR,-1,PALGHAR,MAHARASHTRA,401602: None, None
# Geocoded AT AND POST BORDI,TAL.DAHANUNO.442 ,JAIHIND CHOWK,-1,PALGHAR,MAHARASHTRA,401701: 19.69693, 72.76543
# Geocoded RANGE OFFICE, GOLANI NAKASHOP NO.11-13, DOMS COMPLEX, OPPOSITE PLATINUM HOSPITAL,-1,PALGHAR,MAHARASHTRA,401208: 59.01306, -161.81639
# Geocoded MAHIM ROAD, PALGHARGOKULDHAM SHOPPING CENTRE,,-1,PALGHAR,MAHARASHTRA,401404: 19.6969, 72.7654
# Geocoded ACHOLE ROAD, NALASOPARA (EAST)KARAN A SHOP NO 1-4, 4A, 5&6, MAJITHIA PARK,-1,PALGHAR,MAHARASHTRA,401209: 39.11251, -100.35875
# Geocoded ACHOLE ROAD, NALASOPARA (EAST)KARAN A SHOP NO 1-4, 4A, 5&6, MAJITHIA PARK,-1,PALGHAR,MAHARASHTRA,401209: 39.11251, -100.35875
# Geocoded MAIN ROAD, DAHANUFATIMA BUILDING, MASOLI,,-1,PALGHAR,MAHARASHTRA,401602: 18.5167, 73.5167
# Geocoded AMBADI ROAD CORNER, VASAI WESTSHOP NO 7-9, HIRA NIKETAN,,-1,PALGHAR,MAHARASHTRA,401202: 19.69693, 72.76543
# Geocoded SUTARPADA TALASARICHARNIYA TOWER, GALA NO 1 TO 5 & 8,-1,PALGHAR,MAHARASHTRA,401606: 47.27541, 8.4897
# Geocoded ZENDA CHOWK,AT & POST:- GHOLWAD,-1,PALGHAR,MAHARASHTRA,401702: 20.0847, 72.7289
# Geocoded MAIN ROAD, DAHANUFATIMA BUILDING, MASOLI,,-1,PALGHAR,MAHARASHTRA,401602: 18.5167, 73.5167
# Geocoded TARAPUR ROADSHOP NO. 3 TO 10, KHODARAOM BAUG,,-1,PALGHAR,MAHARASHTRA,401501: 19.69693, 72.76543
# Geocoded LAKSHMIBEN CHHEDA NAGARSHOP NO 3 DHANANJAY AVENUE, PATANKAR PARK,-1,PALGHAR,MAHARASHTRA,401203: 47.27541, 8.4897
# Geocoded SWASTIK PARK, SAPHALE EASTGALA NO 1-5, GROUND FLOOR, SANGAM BUILDING,,-1,PALGHAR,MAHARASHTRA,401102: 19.69693, 72.76543
# Geocoded POST:- UMBARPADA, SAPHALA EAST1st FLOOR, DEVBHOOMI COMPLEX,-1,PALGHAR,MAHARASHTRA,401102: 19.69693, 72.76543
# Geocoded NAVGHAR ROAD, SAMARTH KRUPA NAGAR, VASAI EASTGAURI APARTMENT, AMBICA COMMERICAL COMPLEX,-1,PALGHAR,MAHARASHTRA,401208: None, None
# Geocoded JUCHANDRA ROAD, NAIGAON EASTGROUND FLOOR, SHRI LAXMI PLAZA BUILDING,,-1,PALGHAR,MAHARASHTRA,401208: 47.27541, 8.4897
# Geocoded SHALINI SHANTHARAM SHOPPIN  PADGHESHOP NO. 3,4,7,8,-1,PALGHAR,MAHARASHTRA,421101: 47.27541, 8.4897
# Geocoded PALGHAR BOISAR ROAD, SARAVALIGROUND FLOOR, GEETA MANSION,,-1,PALGHAR,MAHARASHTRA,401501: 19.69693, 72.76543
# Geocoded NEAR POLICE STATIONJIVHALA BUNGLOW,,-1,PALGHAR,MAHARASHTRA,401402: None, None
# Geocoded CHINCHANIVANGAON NAKA, AT & POST CHINCHANI,-1,PALGHAR,MAHARASHTRA,401503: 19.8746, 72.6851
# Geocoded NAVGHAR (E) VASAI EASTGAURI APT.A.C.COMPLEX,,-1,PALGHAR,MAHARASHTRA,401210: 19.69693, 72.76543
# Geocoded ACHOLE ROADSHOP 17 SUNSHINE HEIGHTOP,-1,PALGHAR,MAHARASHTRA,401209: 20.1171, 73.2565
# Geocoded STATION ROAD, VANGAON WESTTARE HOUSE, NEAR RAILWAY STATION,-1,PALGHAR,MAHARASHTRA,401103: None, None
# Geocoded MANVEL PADA, VIRAR EASTGROUND FLOOR, VIDYA SADAN,-1,PALGHAR,MAHARASHTRA,401305: 19.69693, 72.76543
# Geocoded AT & POST MASWAN, ISTRICT:- PALGHARHOUSE NO 223,,-1,PALGHAR,MAHARASHTRA,401404: 19.69693, 72.76543
# Geocoded MAIN ROAD, OPPOSITE KAILAS THEATRE, WADAGROUND FLOOR, DAHE SOCIETY, TDCC BANK BUILDING,,-1,PALGHAR,MAHARASHTRA,421303: None, None
# Geocoded PALGHARMANOR ROAD,,-1,PALGHAR,MAHARASHTRA,401404: 19.6969, 72.7654
# Geocoded BOISAR ROAD UMROLIAT PO UMROLI NEAR MARATHI SCHOOL,-1,PALGHAR,MAHARASHTRA,401501: None, None
# Geocoded SARASWATI BAUG, VIVA COLLEGE ROAD, VIRAR WESTGROUND FLOOR, SHOP NO.3/11, SUYASH BUILDING,-1,PALGHAR,MAHARASHTRA,401303: 62.0, 10.0
# Geocoded AMBADI ROAD CORNER, VASAI WESTSHOP NO 7-9, HIRA NIKETAN,,-1,PALGHAR,MAHARASHTRA,401202: 19.69693, 72.76543
# Geocoded NAVGHAR ROAD, SAMARTH KRUPA NAGAR, VASAI EASTGAURI APARTMENT, AMBICA COMMERICAL COMPLEX,-1,PALGHAR,MAHARASHTRA,401208: None, None
# Geocoded ACHOLE ROAD, NALASOPARA (EAST)KARAN A SHOP NO 1-4, 4A, 5&6, MAJITHIA PARK,-1,PALGHAR,MAHARASHTRA,401209: 39.11251, -100.35875
# Geocoded MAHIM ROAD, PALGHARGOKULDHAM SHOPPING CENTRE,,-1,PALGHAR,MAHARASHTRA,401404: 19.6969, 72.7654
# Geocoded TARAPUR ROADSHOP NO. 3 TO 10, KHODARAOM BAUG,,-1,PALGHAR,MAHARASHTRA,401501: 19.69693, 72.76543
# Geocoded MANVEL PADA, VIRAR EASTGROUND FLOOR, VIDYA SADAN,-1,PALGHAR,MAHARASHTRA,401305: 19.69693, 72.76543
# Geocoded ACHOLE ROAD, NALASOPARA (EAST)KARAN A SHOP NO 1-4, 4A, 5&6, MAJITHIA PARK,-1,PALGHAR,MAHARASHTRA,401209: 39.11251, -100.35875
# Geocoded Rashmi Star City Naigaon,Juchandra Palghar Maharashtra,MH303 A14,-1,PALGHAR,MAHARASHTRA,401208: 19.69693, 72.76543
# Geocoded KANSAI SECTION,AMBARNATH,THANE,MAHARASHTRA,MHPLOT NO.346,SHOP NO.6,-1,PALGHAR,MAHARASHTRA,421501: 47.27541, 8.4897
# Geocoded NEW AZAD NAGAR  NR QADRIYA MASJID SHANTINAGAR  BHIWANDI  THANE  MH MHH.N.1764,-1,PALGHAR,MAHARASHTRA,421302: 7.113, 171.236
# Geocoded TRIVEDI NAGAR  SARAWALI SARAWALI  PALGHAR  MAHARASHTRA MHFLAT NO.3/F4,-1,PALGHAR,MAHARASHTRA,401501: 47.27541, 8.4897
# Geocoded BEHIND MARUTI MANDIR  KACHERIPADA BHIWANDI  THANE  DANDEKARWADI  MAHARASHT MH6 3,-1,PALGHAR,MAHARASHTRA,421301: 26.91667, 87.91667
# Geocoded BALAJI NAGAR  BHANDARI RD THANE OPP  ANKIT MEDICAL  BHIWANDI  THANE  MH MH53 2,-1,PALGHAR,MAHARASHTRA,421305: 19.30023, 73.05881
# Geocoded 3 F4  TRIVEDI NAGAR  SARAWALI SARAWALI  PALGHAR  MAHARASHTRA MHFLAT NO,-1,PALGHAR,MAHARASHTRA,401501: 19.69693, 72.76543
# Geocoded KURGAON PALGHAR MHAT PO,-1,PALGHAR,MAHARASHTRA,401502: 19.7986, 73.094
# Geocoded Tina Apartment Bedekar Nagar District Thane Maharashtra MHAt Post,-1,PALGHAR,MAHARASHTRA,400612: 19.69693, 72.76543
# Geocoded Mokhada,Thane Maharashtra,MHKaregaon Kniste,-1,PALGHAR,MAHARASHTRA,401604: 19.9365, 73.3403
# Geocoded Road Near Block No A-102,Kurla Camp, Ulhasnagar, Thane,MHShiv Mandir,-1,PALGHAR,MAHARASHTRA,421004: None, None
# Geocoded VASAI THANE MHCHINCHOLI,-1,PALGHAR,MAHARASHTRA,401208: 19.3547, 72.9094
# Geocoded NALLASOPARA EAST VASAI DISTRICT THANE MAHARASHTRA MHAT ALKAPURI,-1,PALGHAR,MAHARASHTRA,401209: 19.69693, 72.76543
# Geocoded SAI HERITAGE VIRAR EAST VASAI  PALGHAR  MAHARASHTRA MHVAISHNAVI PLAZA,-1,PALGHAR,MAHARASHTRA,401305: 47.27541, 8.4897
# Geocoded 2  SURESH PATIL CHAWL ATALI RD THANE MANGAL NAGAR  AMBIVALI W  KALYAN  MH MHR N,-1,PALGHAR,MAHARASHTRA,421102: -0.61179, 30.55573
# Geocoded NR TALATHI OFFC BADLAPUR  THANE  MAHARASHTRA MHORIENT LEGACY,-1,PALGHAR,MAHARASHTRA,421503: 19.69693, 72.76543
# Geocoded PRASANNA LANE  AMBARNATH THANE  MAHARASHTRA MHSUNDARAM CHS,-1,PALGHAR,MAHARASHTRA,421501: 19.69693, 72.76543
# Geocoded PAUL KOCHAI VADIPADA DISTRICT THANE MAHARASHTRA MHAT JHULTA,-1,PALGHAR,MAHARASHTRA,401606: 19.69693, 72.76543
# Geocoded NR OLD GAJANAN HOUSE  KALYAN BANDARPADA  THANE  MAHARASHTRA MHMOHANA RD,-1,PALGHAR,MAHARASHTRA,421103: None, None
# Geocoded THANE MHBHAYNDER WEST,-1,PALGHAR,MAHARASHTRA,401101: 28.9416, 77.0959
# Geocoded CLG  DOMBIVLI E  KALYAN THANE  MAHARASHTRA MHNR PRAGATI,-1,PALGHAR,MAHARASHTRA,421201: 19.69693, 72.76543
# Geocoded 509 Annapurna Kirana Store Asbibi Khadan Road Near Good Luck Hotel MHHouse No,-1,PALGHAR,MAHARASHTRA,421302: None, None
# Geocoded Chavindra Road  Gorsai Near Vaibhav Chowk  Gorsai  Thane MHSitabai Nagar,-1,PALGHAR,MAHARASHTRA,421302: None, None
# Geocoded Palghar   MAHARASHTRAMHTelvapada AsangoanDisst,-1,PALGHAR,MAHARASHTRA,401103: 19.8762, 72.7627
# Geocoded satpati   Thane PalgharDissst Palghar   MAHARASHTRAMHDanda Pada,-1,PALGHAR,MAHARASHTRA,401405: 18.6588, 72.9519
# Geocoded CBD BELAPURTHANEMHCBD BELAPURTHANEMH,-1,PALGHAR,MAHARASHTRA,400614: 19.202, 72.9725

# %%
#with google maps api
import requests
import pandas as pd
import time

# Your Google Maps API Key
API_KEY = 'AIzaSyB1NJPGWcEcqoC7WZYCOcBO3EFIYfiQzEI'

# Load dataset (CSV file with an 'address' column)
input_file = '/Users/Supriya/Downloads/RBI_bank_palghar - Sheet1.csv'
output_file = '/Users/Supriya/Downloads/geocoded_addresses_google_maps.csv'

# Read the input CSV into a DataFrame
df = pd.read_csv(input_file)

# Create empty columns for latitude and longitude
df['latitude'] = None
df['longitude'] = None

# Function to geocode an address using Google Maps API
def geocode_Address(Address):
    geocode_url = f'https://maps.googleapis.com/maps/api/geocode/json?address={Address}&key={API_KEY}'
    response = requests.get(geocode_url)
    geocode_data = response.json()
    
    # If response is OK, extract latitude and longitude
    if geocode_data['status'] == 'OK':
        location = geocode_data['results'][0]['geometry']['location']
        return location['lat'], location['lng']
    else:
        print(f"Geocoding failed for address: {Address}, Status: {geocode_data['status']}")
        return None, None

# Geocode each address in the DataFrame
for idx, row in df.iterrows():
    Address = row['Address']
    
    # Call the geocoding function
    lat, lng = geocode_Address(Address)
    
    # Save the result back to the DataFrame
    df.at[idx, 'latitude'] = lat
    df.at[idx, 'longitude'] = lng
    
    # Print progress
    if idx % 100 == 0:
        print(f"Processed {idx + 1}/{len(df)} Addresses")
    
    # Sleep to avoid exceeding the API rate limit (50 requests per second)
    time.sleep(0.1)  # 100 ms

# Save the geocoded data to a new CSV file
df.to_csv(output_file, index=False)

print(f"Geocoding completed. Results saved to {output_file}")


##Faster and lesser Nulls (~2%) -- 40,000 entries free geocoding
# Out:
# Processed 1/810 Addresses
# Geocoding failed for address: JawharInternet Caf&eacute;  Pach Batti  Sambaji Chowk Internet Caf&eacute;,-1,PALGHAR,MAHARASHTRA,401603, Status: ZERO_RESULTS
# Processed 101/810 Addresses
# Geocoding failed for address: TAPS 3 & 4NPCIL, TMS TARAPUR BOISAR, TALUKA PALGHAR,-1,PALGHAR,MAHARASHTRA,401504, Status: ZERO_RESULTS
# Geocoding failed for address: TAPS 3 & 4NPCIL, TMS TARAPUR BOISAR, TALUKA PALGHAR,-1,PALGHAR,MAHARASHTRA,401504, Status: ZERO_RESULTS
# Processed 201/810 Addresses
# Geocoding failed for address: PALGHARAT & POST WADA TALUKA WADA,-1,PALGHAR,MAHARASHTRA,421303, Status: ZERO_RESULTS
# Processed 301/810 Addresses
# Geocoding failed for address: At & Post ASE, Taluka - Mokhada882/1043, GRAM PANCHAYAT OFFICE,-1,PALGHAR,MAHARASHTRA,401604, Status: ZERO_RESULTS
# Processed 401/810 Addresses
# Geocoding failed for address: CHIKHALEAT & POST - CHIKHALE, NEAR HANUMAN MANDIR,-1,PALGHAR,MAHARASHTRA,401602, Status: ZERO_RESULTS
# Geocoding failed for address: AT & POST MASWAN, ISTRICT:- PALGHARHOUSE NO 223,,-1,PALGHAR,MAHARASHTRA,401404, Status: ZERO_RESULTS
# Geocoding failed for address: CHIKHALEAT & POST - CHIKHALE, NEAR HANUMAN MANDIR,-1,PALGHAR,MAHARASHTRA,401602, Status: ZERO_RESULTS
# Geocoding failed for address: AT & POST MASWAN, ISTRICT:- PALGHARHOUSE NO 223,,-1,PALGHAR,MAHARASHTRA,401404, Status: ZERO_RESULTS
# Geocoding failed for address: .AT & POST SATPATI, TALUKA PALGHAR, DIST. THANE, MAHARASHTRA - 401405,-1,PALGHAR,MAHARASHTRA,401405, Status: ZERO_RESULTS
# Geocoding failed for address: AMBADIGROUND FLOOR,SHOP NO 2&3 VISHWAKARMA,BLDG NO VASAI (WEST),-1,PALGHAR,MAHARASHTRA,401202, Status: ZERO_RESULTS
# Processed 501/810 Addresses
# Geocoding failed for address: .AT & POST SATPATI, TALUKA PALGHAR, DIST. THANE, MAHARASHTRA - 401405,-1,PALGHAR,MAHARASHTRA,401405, Status: ZERO_RESULTS
# Geocoding failed for address: AMBADIGROUND FLOOR,SHOP NO 2&3 VISHWAKARMA,BLDG NO VASAI (WEST),-1,PALGHAR,MAHARASHTRA,401202, Status: ZERO_RESULTS
# Geocoding failed for address: .AT & POST SATPATI, TALUKA PALGHAR, DIST. THANE, MAHARASHTRA - 401405,-1,PALGHAR,MAHARASHTRA,401405, Status: ZERO_RESULTS
# Geocoding failed for address: HOLINAKA,AT&POST ARNALASAMANTH BLDG,,-1,PALGHAR,MAHARASHTRA,401302, Status: ZERO_RESULTS
# Geocoding failed for address: HOLINAKA,AT&POST ARNALASAMANTH BLDG,,-1,PALGHAR,MAHARASHTRA,401302, Status: ZERO_RESULTS
# Processed 601/810 Addresses
# Geocoding failed for address: NEAR VIVA COLLEGE, BYPASS ROAD#11, GROUND FLOOR, AMBO PATIL ESTATE VIRAR WEST,-1,PALGHAR,MAHARASHTRA,401303, Status: REQUEST_DENIED
# Geocoding failed for address: KUDUS KHANIVLI ROAD, TARF POULBARHOUSE NO.214, GALA NO.1,2 & 3 KHARIVALI TARF POULBAR,-1,PALGHAR,MAHARASHTRA,421312, Status: ZERO_RESULTS
# Geocoding failed for address: NEAR VIVA COLLEGE, BYPASS ROAD#11, GROUND FLOOR, AMBO PATIL ESTATE VIRAR WEST,-1,PALGHAR,MAHARASHTRA,401303, Status: REQUEST_DENIED
# Processed 701/810 Addresses
# Processed 801/810 Addresses
# Geocoding completed. Results saved to /Users/Supriya/Downloads/geocoded_addresses_google_maps.csv
